# %%
import pandas as pd

# %%
a=["prasad","prabhas","sri devi","anushka"]
r=pd.Series(a,index=[15,25,65,767,])
print(r)
# Out:
# 15       prasad
# 25      prabhas
# 65     sri devi
# 767     anushka
# dtype: object

# %%
r=pd.read_csv("/content/drive/MyDrive/diabetcsv.csv")
print(r)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
r=pd.read_csv("/content/drive/MyDrive/diabetcsv.csv")
print(r.head())
print(r.tail())
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.head())
print("tail")
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# tail
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.describe().T)
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv",sep=" ")
print(df)
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv",sep=" ")
print(df.describe().T)
# Out:
#                                            count unique  \
# Names,Initials,SEM1,SEM2,SEM3,Grade,Placed    17     16
#
#                                                                  top freq
# Names,Initials,SEM1,SEM2,SEM3,Grade,Placed  Rajesh,M,8.9,9.1,9.3,A,1    2

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (17, 7)
# 17
# 7

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv",sep=" ")
print(df.columns)
l1=list(df.columns)
print(l1)
# Out:
# Index(['Names,Initials,SEM1,SEM2,SEM3,Grade,Placed'], dtype='object')
# ['Names,Initials,SEM1,SEM2,SEM3,Grade,Placed']

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv" )
df2=df.copy()
df2.loc[3:9,'SEM1']=None
df2.head(17)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   NaN   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False   True  False   True  False   False
# 4  False     False   True  False  False  False   False
# 5  False     False   True  False  False  False   False
# 6  False     False   True  False  False  False   False

# %%
print(df2.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        8
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
print(df2.isnull().sum().sum())
# Out:
# 9

# %%
print(df['SEM1'])
# Out:
# 0     9.8
# 1     8.9
# 2     9.9
# 3     7.7
# 4     9.8
# 5     8.9
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
print(df[['SEM1','Names']])
# Out:
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    9.9  Kissan
# 3    7.7    Mary
# 4    9.8    Jeen
# 5    8.9     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark

# %%
print(df[df.index==6])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 6  Hassan        V   9.9   9.0   9.2     A       1

# %%
print(df[df.index.isin(range(2,8))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1

# %%
print(df2.loc[1])
# Out:
# Names       Rajesh
# Initials         M
# SEM1           8.9
# SEM2           9.1
# SEM3           9.3
# Grade            A
# Placed           1
# Name: 1, dtype: object

# %%
df2.loc[6:11]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 6   Hassan        V   NaN   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0

# %%
df2.loc[[10,4,8]]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10  Kiran        V   NaN   9.3   9.2     A       0
# 4    Jeen        K   NaN   9.1   9.9    A+       1
# 8    Jess        K   NaN   9.1   9.9    A+       1

# %%
df2.loc[10:15,['Names','Grade']]
# Out:
#      Names Grade
# 10   Kiran     A
# 11    Maya     B
# 12   Jolin    A+
# 13  Rajesh     A
# 14    Riya     A
# 15    Sana     A

# %%
df2.iloc[10:15, :4]
# Out:
#      Names Initials  SEM1  SEM2
# 10   Kiran        V   NaN   9.3
# 11    Maya        N   7.7   8.0
# 12   Jolin        K   9.8   9.1
# 13  Rajesh        M   8.9   9.1
# 14    Riya        M   9.3   9.9

# %%
df2.loc[:6,["Names","SEM1"]]
# Out:
#     Names  SEM1
# 0     Joe   9.8
# 1  Rajesh   8.9
# 2  Kissan   9.9
# 3    Mary   NaN
# 4    Jeen   NaN
# 5     Raj   NaN
# 6  Hassan   NaN

# %%
df2.loc[df['Names']=='Joe']
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df.loc[df['SEM1']>9.0,['Names']]
# Out:
#      Names
# 0      Joe
# 2   Kissan
# 4     Jeen
# 6   Hassan
# 12   Jolin
# 14    Riya
# 15    Sana

# %%
df3=df2.copy()
print(df3)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   NaN   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True,axis=1)
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3.dropna(inplace=True,how='all')
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
dfn=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
dfn
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mv=dfn['SEM1'].mean()
dfn=dfn.fillna(mv)
print(dfn)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
dfn=dfn.drop_duplicates()
print(dfn)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
dfn.rename(columns={'Grade':'GPA'},inplace=True)
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2       SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.900000  A+       1
# 1  Rajesh        M   8.9   9.1   9.300000   A       1
# 2  Kissan        V   9.9   9.8  10.000000   A       0
# 3    Mary        N   7.7   8.0   8.992857   B       0
# 4    Jeen        K   9.8   9.1   9.900000  A+       1

# %%
dfn.columns=['student_name','mr/ms','1stsem','2ndsem','3rdsem','F_Outcome','placed?']
dfn.head()
# Out:
#   student_name mr/ms  1stsem  2ndsem     3rdsem F_Outcome  placed?
# 0          Joe     K     9.8    10.0   9.900000        A+        1
# 1       Rajesh     M     8.9     9.1   9.300000         A        1
# 2       Kissan     V     9.9     9.8  10.000000         A        0
# 3         Mary     N     7.7     8.0   8.992857         B        0
# 4         Jeen     K     9.8     9.1   9.900000        A+        1

# %%
dfn['Avg_score'] = (dfn['1stsem']+dfn['2ndsem']+dfn['3rdsem'])/3
dfn.head()
# Out:
#   student_name mr/ms  1stsem  2ndsem     3rdsem F_Outcome  placed?  Avg_score
# 0          Joe     K     9.8    10.0   9.900000        A+        1   9.900000
# 1       Rajesh     M     8.9     9.1   9.300000         A        1   9.100000
# 2       Kissan     V     9.9     9.8  10.000000         A        0   9.900000
# 3         Mary     N     7.7     8.0   8.992857         B        0   8.230952
# 4         Jeen     K     9.8     9.1   9.900000        A+        1   9.600000

# %%
dfn.groupby('placed?').min(4)
dfn
# Out:
#    student_name mr/ms    1stsem  2ndsem     3rdsem F_Outcome  placed?  \
# 0           Joe     K  9.800000    10.0   9.900000        A+        1
# 1        Rajesh     M  8.900000     9.1   9.300000         A        1
# 2        Kissan     V  9.900000     9.8  10.000000         A        0
# 3          Mary     N  7.700000     8.0   8.992857         B        0
# 4          Jeen     K  9.800000     9.1   9.900000        A+        1
# 5           Raj     M  8.900000     9.1   9.300000         A        1
# 6        Hassan     V  9.900000     9.0   9.200000         A        1
# 7          Mari     N  7.700000     8.0   7.100000         B        1
# 8          Jess     K  8.992857     9.1   9.900000        A+        1
# 9        Rajini     M  8.992857     9.1   9.300000         A        0
# 10        Kiran     V  8.992857     9.3   9.200000         A        0
# 11         Maya     N  7.700000     8.0   7.100000         B        0
# ...

# %%
dfn[['3rdsem', '2ndsem']].plot.line()
# Out:
# <Axes: >

# %%
dfn.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
runs = np.array([100,50,91,78,89,25,34,19,9,10])
w = np.array([1,0,2,0,3,7,8,9,7,5])
plt.plot(runs,w,color='pink')
plt.title('IndvsAus_score')
#plt.bar(runs_i,w,colour='pink',label='ind')
plt.legend(loc='best')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Generate array of 200 values between -pi & pi
tigar = np.linspace(-2*np.pi, 2*np.pi, 100)
print(tigar)

plt.plot(tigar, np.sin(tigar) ,color='blue',linestyle='dotted') # SIN
#plt.plot(x,y,,color,labels....)
plt.title("sin(x)")
# Display plot
plt.show()
# Out:
# [-6.28318531 -6.15625227 -6.02931923 -5.9023862  -5.77545316 -5.64852012
#  -5.52158709 -5.39465405 -5.26772102 -5.14078798 -5.01385494 -4.88692191
#  -4.75998887 -4.63305583 -4.5061228  -4.37918976 -4.25225672 -4.12532369
#  -3.99839065 -3.87145761 -3.74452458 -3.61759154 -3.4906585  -3.36372547
#  -3.23679243 -3.10985939 -2.98292636 -2.85599332 -2.72906028 -2.60212725
#  -2.47519421 -2.34826118 -2.22132814 -2.0943951  -1.96746207 -1.84052903
#  -1.71359599 -1.58666296 -1.45972992 -1.33279688 -1.20586385 -1.07893081
#  -0.95199777 -0.82506474 -0.6981317  -0.57119866 -0.44426563 -0.31733259
#  -0.19039955 -0.06346652  0.06346652  0.19039955  0.31733259  0.44426563
#   0.57119866  0.6981317   0.82506474  0.95199777  1.07893081  1.20586385
#   1.33279688  1.45972992  1.58666296  1.71359599  1.84052903  1.96746207
#   2.0943951   2.22132814  2.34826118  2.47519421  2.60212725  2.72906028
#   2.85599332  2.98292636  3.10985939  3.23679243  3.36372547  3.4906585
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
#creating x
overs = np.arange(5,50,5)
overs_a = np.arange(5,30,5)
#creating y
runs_i = np.array([25,51,84,131,160,189,220,250,267])
runs_a = np.array([15,41,94,110,151])
wickets = np.array([12,32,96])
#plotting
plt.bar(overs,runs_i,color='blue',label='India')
plt.bar(overs_a,runs_a,color='yellow',label = 'Aus')
#combining two graphs
plt.legend(loc='best')
#displaying the final graph
plt.show()

# %%
import matplotlib.pyplot as plt
a = [230,560,780,127,128]
b = [200,160,270,127,400]
years = [1,2,3,4]
profit_a = [(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b = [(b[i]-b[i-1]) for i in range(1,len(b))]
plt.subplot(2,1,2)
plt.plot(years,profit_a,color='hotpink',linewidth = '7',label =
'CompanyA',marker='>',ms='20',mec='k')
plt.subplot(2,1,1)
plt.plot(years,profit_b,color='black',linestyle='dotted',label =
'CompanyB',marker = 'H')
plt.show()

# %%
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
color=['green','red','blue','yellow']
plt.pie(a,labels = labe,colors=color)
explo = [0.5,0,0,0]
plt.pie(a,labels = labe,explode = explo,shadow=True)

plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tipss=sns.load_dataset("iris")
print(iris)
sns.scatterplot(x="sepal_length",y="petal_length",data=tips)
plt.title("iris")
plt.xlabel("sepal_length($)")
plt.ylabel("petal_length($)")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tipss=sns.load_dataset("iris")
print(iris)
sns.barplot(x="sepal_length",y="petal_length",data=tips)
plt.title("iris")
plt.xlabel("sepal_length($)")
plt.ylabel("petal_length($)")
plt.legend()
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tipss=sns.load_dataset("iris")
print(iris)
sns.boxplot(x="sepal_length",y="petal_length",data=tips)
plt.title("iris")
plt.xlabel("sepal_length($)")
plt.ylabel("petal_length($)")
plt.legend()
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
print(tips)
sns.violinplot(x="day",y="tip",data=tips)
plt.title("violinplot graph")
plt.xlabel("day($)")
plt.ylabel("total_bill($)")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
print(tips)
sns.jointplot(x="day",y="tip",data=tips)
plt.title("violinplot graph")
plt.xlabel("day($)")
plt.ylabel("total_bill($)")
plt.legend()
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
a=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
b=sns.lineplot(x='Names',y='Grade',data=a)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plot
iris=sns.load_dataset("iris")
correlation_matrix=iris.corr()
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
plt.title("correlation heatmap")
plt.show()
# Out:
# <ipython-input-99-3a01ca64c69a>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=iris.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
print(tips)
sns.countplot(x="day",data=tips)
plt.title("violinplot graph")
plt.xlabel("day")
plt.ylabel("total_bill")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
print(tips)
sns.lmplot(x="total_bill",y="tip",data=tips)
plt.title("violinplot graph")
plt.xlabel("day($)")
plt.ylabel("total_bill($)")
plt.legend()
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
g=sns.FacetGrid(tips, col="day")
g.map(sns.histplot,"day")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("tips of workers")
plt.show()
